# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame
import matplotlib.pyplot as plt

# %%
import tensorflow as tf

# %%
mnist=tf.keras.datasets.mnist

# %%
mnist
# Out:
# <module 'tensorflow_core.keras.datasets.mnist' from 'C:\\Users\\jhatu\\Anaconda\\lib\\site-packages\\tensorflow_core\\python\\keras\\api\\_v2\\keras\\datasets\\mnist\\__init__.py'>

# %%
(X_train,y_train),(x_test,y_test)=mnist.load_data()
X_train,X_test=X_train/255.0,x_test/255.0

# %%
model=tf.keras.models.Sequential([tf.keras.layers.Flatten(input_shape=(28,28)),
                                 tf.keras.layers.Dense(128,activation='relu'),
                                 tf.keras.layers.Dropout(0.2),
                                 tf.keras.layers.Dense(10,activation='softmax')])

# %%
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train,y_train,epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 6s 108us/sample - loss: 0.2920 - accuracy: 0.9152
# Epoch 2/5
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.1386 - accuracy: 0.9584
# Epoch 3/5
# 60000/60000 [==============================] - 5s 91us/sample - loss: 0.1037 - accuracy: 0.9686
# Epoch 4/5
# 60000/60000 [==============================] - 5s 87us/sample - loss: 0.0824 - accuracy: 0.9746
# Epoch 5/5
# 60000/60000 [==============================] - 5s 86us/sample - loss: 0.0720 - accuracy: 0.9778

# %%
model.evaluate(x_test,y_test)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [11.40686440358758, 0.9775]
